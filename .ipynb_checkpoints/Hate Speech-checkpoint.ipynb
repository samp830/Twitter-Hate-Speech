# %% [markdown]
# # Analyzing Hate Speech on Twitter

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
from sklearn import linear_model, datasets, model_selection 
from sklearn.cross_validation import cross_val_score
import re
# Out:
# /Users/sparajuli/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
#Read CSV
text = pd.read_csv('twitter.csv', encoding = "ISO-8859-1")
#Default UTF-8 encoding was returning an error, ISO is fine to use because dataset is in English
text.head()
# Out:
#     _unit_id _golden _unit_state  _trusted_judgments _last_judgment_at  \
# 0  853718217    True      golden                  86               NaN
# 1  853718218    True      golden                  92               NaN
# 2  853718219    True      golden                  86               NaN
# 3  853718220    True      golden                  98               NaN
# 4  853718221    True      golden                  88               NaN
#
#                  does_this_tweet_contain_hate_speech  \
# 0  The tweet uses offensive language but not hate...
# 1                     The tweet contains hate speech
# 2                     The tweet contains hate speech
# 3                     The tweet contains hate speech
# 4  The tweet uses offensive language but not hate...
#
#    does_this_tweet_contain_hate_speech:confidence  _created_at orig__golden  \
# 0                                          0.6013          NaN         True
# 1                                          0.7227          NaN         True
# 2                                          0.5229          NaN         True
# 3                                          0.5184          NaN         True
# 4                                          0.5185          NaN         True
#
#    orig__last_judgment_at  orig__trusted_judgments  orig__unit_id  \
# 0                     NaN                      0.0    615561535.0
# 1                     NaN                      0.0    615561723.0
# 2                     NaN                      0.0    615562039.0
# 3                     NaN                      0.0    615562068.0
# 4                     NaN                      0.0    615562488.0
#
#   orig__unit_state  _updated_at orig_does_this_tweet_contain_hate_speech  \
# 0           golden          NaN           The tweet contains hate speech
# 1           golden          NaN           The tweet contains hate speech
# 2           golden          NaN           The tweet contains hate speech
# 3           golden          NaN           The tweet contains hate speech
# 4           golden          NaN           The tweet contains hate speech
#
#             does_this_tweet_contain_hate_speech_gold  \
# 0  The tweet contains hate speech\nThe tweet uses...
# 1  The tweet contains hate speech\nThe tweet uses...
# 2  The tweet contains hate speech\nThe tweet uses...
# 3  The tweet contains hate speech\nThe tweet uses...
# 4  The tweet contains hate speech\nThe tweet uses...
#
#    does_this_tweet_contain_hate_speech_gold_reason  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    does_this_tweet_contain_hate_speechconfidence      tweet_id  \
# 0                                            1.0  1.666196e+09
# 1                                            1.0  4.295121e+08
# 2                                            1.0  3.956238e+08
# 3                                            1.0  4.975147e+08
# 4                                            1.0  5.889236e+08
#
#                                           tweet_text
# 0       Warning: penny boards will make you a faggot
# 1                                         Fuck dykes
# 2  @sizzurp__ @ILIKECATS74 @yoPapi_chulo @brandon...
# 3  "@jayswaggkillah: "@JacklynAnnn: @jayswaggkill...
# 4  @Zhugstubble You heard me bitch but any way I'...

# %%
#Selecting Relevant Columns
columns_of_interest = ['does_this_tweet_contain_hate_speech','does_this_tweet_contain_hate_speech:confidence', 'tweet_text']
text = text[columns_of_interest]
text
# Out:
#                      does_this_tweet_contain_hate_speech  \
# 0      The tweet uses offensive language but not hate...
# 1                         The tweet contains hate speech
# 2                         The tweet contains hate speech
# 3                         The tweet contains hate speech
# 4      The tweet uses offensive language but not hate...
# 5                         The tweet contains hate speech
# 6                         The tweet contains hate speech
# 7                         The tweet contains hate speech
# 8      The tweet uses offensive language but not hate...
# 9      The tweet uses offensive language but not hate...
# 10                        The tweet contains hate speech
# 11                        The tweet contains hate speech
# 12                        The tweet contains hate speech
# 13                        The tweet contains hate speech
# 14                        The tweet contains hate speech
# 15                        The tweet contains hate speech
# 16                        The tweet contains hate speech
# 17     The tweet uses offensive language but not hate...
# 18                        The tweet contains hate speech
# 19     The tweet uses offensive language but not hate...
# 20                        The tweet contains hate speech
# 21                        The tweet contains hate speech
# 22                            The tweet is not offensive
# 23                            The tweet is not offensive
# 24                            The tweet is not offensive
# 25                            The tweet is not offensive
# 26                            The tweet is not offensive
# 27                            The tweet is not offensive
# 28                            The tweet is not offensive
# 29                            The tweet is not offensive
# ...                                                  ...
# 14479                         The tweet is not offensive
# 14480                         The tweet is not offensive
# 14481                         The tweet is not offensive
# 14482                         The tweet is not offensive
# 14483                     The tweet contains hate speech
# 14484                         The tweet is not offensive
# 14485                         The tweet is not offensive
# 14486                         The tweet is not offensive
# 14487                         The tweet is not offensive
# 14488                         The tweet is not offensive
# 14489  The tweet uses offensive language but not hate...
# 14490                     The tweet contains hate speech
# 14491  The tweet uses offensive language but not hate...
# 14492                         The tweet is not offensive
# 14493                         The tweet is not offensive
# 14494                         The tweet is not offensive
# 14495                         The tweet is not offensive
# 14496                         The tweet is not offensive
# 14497                         The tweet is not offensive
# 14498                         The tweet is not offensive
# 14499                         The tweet is not offensive
# 14500                         The tweet is not offensive
# 14501                         The tweet is not offensive
# 14502                         The tweet is not offensive
# 14503                         The tweet is not offensive
# 14504                         The tweet is not offensive
# 14505                         The tweet is not offensive
# 14506                         The tweet is not offensive
# 14507                         The tweet is not offensive
# 14508                         The tweet is not offensive
#
#        does_this_tweet_contain_hate_speech:confidence  \
# 0                                              0.6013
# 1                                              0.7227
# 2                                              0.5229
# 3                                              0.5184
# 4                                              0.5185
# 5                                              0.8816
# 6                                              0.5207
# 7                                              0.5619
# 8                                              0.6419
# 9                                              0.6407
# 10                                             0.7619
# 11                                             0.5606
# 12                                             0.8435
# 13                                             0.8414
# 14                                             0.8826
# 15                                             0.7620
# 16                                             0.6833
# 17                                             0.5204
# 18                                             0.6410
# 19                                             0.6419
# 20                                             0.7608
# 21                                             0.9221
# 22                                             1.0000
# 23                                             1.0000
# 24                                             0.9218
# 25                                             0.9204
# 26                                             1.0000
# 27                                             0.8388
# 28                                             1.0000
# 29                                             1.0000
# ...                                               ...
# 14479                                          1.0000
# 14480                                          0.6771
# 14481                                          1.0000
# 14482                                          0.6683
# 14483                                          0.6684
# 14484                                          1.0000
# 14485                                          0.3351
# 14486                                          0.6615
# 14487                                          1.0000
# 14488                                          1.0000
# 14489                                          1.0000
# 14490                                          0.6633
# 14491                                          0.6616
# 14492                                          1.0000
# 14493                                          1.0000
# 14494                                          0.6579
# 14495                                          1.0000
# 14496                                          1.0000
# 14497                                          1.0000
# 14498                                          1.0000
# 14499                                          1.0000
# 14500                                          0.6684
# 14501                                          1.0000
# 14502                                          1.0000
# 14503                                          1.0000
# 14504                                          0.3418
# 14505                                          0.6804
# 14506                                          1.0000
# 14507                                          1.0000
# 14508                                          1.0000
#
#                                               tweet_text
# 0           Warning: penny boards will make you a faggot
# 1                                             Fuck dykes
# 2      @sizzurp__ @ILIKECATS74 @yoPapi_chulo @brandon...
# 3      "@jayswaggkillah: "@JacklynAnnn: @jayswaggkill...
# 4      @Zhugstubble You heard me bitch but any way I'...
# 5      @elaynay your a dirty terrorist and your relig...
# 6      RT @ivanrabago_: @_WhitePonyJr_ looking like f...
# 7      Well I thought you knew actually RT @KingHorse...
# 8           @Stonisnipezz I know. It was a joke, faggot.
# 9      I'm tired of people saying I look like my brot...
# 10     #VoteBlue2014 Yeah. CUZ 8 million people in fa...
# 11     @AndreBerto word is you use roids, stupid hypo...
# 12                               I hate faggots like you
# 13     @MoriTaheripour shut up nigger whore! Hope u g...
# 14     @Oprah @3LWTV Fuck you nigger sheboon. Hope yo...
# 15     They used to tie both ends of a niggers legs t...
# 16     Good night fags and fagettes (that's the femal...
# 17     I cant stand no crybaby ass nigga. If you gonn...
# 18     RT @nerdkiller669: @ShinSnipes no you're a nigger
# 19     "I'll fuck you til you love me faggot" - Mike ...
# 20     @OxbloodStomper @PalePixie88 @SlaveCatcher88 w...
# 21     I fucking hate you niggers bruh... http://t.co...
# 22     RT @Fact: Some species of birds have been know...
# 23     I remember Draft prom night, my dress wouldn't...
# 24     Damn Eli. That's just ruff. I'm not even gonna...
# 25     Also, Happy Armistice Day, anachronists!\n\n&#...
# 26     @ExpSelf A friend suggested I dress as a Fairy...
# 27     RT @BitchPlsComedy: apparently &#8220;bae&#822...
# 28     @RiotSupport so I was suspended for a day beca...
# 29     #Flyers w/ some moxy! Big comeback again!!! Ma...
# ...                                                  ...
# 14479  I can't deal with a slow internet connection. ...
# 14480  Mental Health Practitioner  - Coon Rapids Day ...
# 14481  Mental Health Practitioner  - Coon Rapids Day ...
# 14482  Mental Health Practitioner  - Coon Rapids Day ...
# 14483  Ben Carson thinks it's okay to have A confeder...
# 14484  #YodaSpeakASaying \n\nKills, captivity does.\n...
# 14485  diamond keep actin up ima go to her job and be...
# 14486  Cries. I'm turning into a weeb-coon https://t....
# 14487  Saw this gorgeous 4 1/2 year old Maine Coon to...
# 14488  Jet Stream the Maine Coon riding out last nigh...
# 14489          @LenaOverFlowers I'm not even a coon girl
# 14490  From what I've seen men and women coon at the ...
# 14491  "BW,take care of me! pls buy my coon ass somet...
# 14492  Interesting data on quantifying value of the I...
# 14493                       @aryan_twr60 thank you_Ì«ÌÐ_
# 14494  @sardesairajdeep @DwaipayanM if he is Aryan th...
# 14495  @sardesairajdeep sir if he is Aryan then #mall...
# 14496  Radio Nordfront interview a Russian patriot an...
# 14497  @nupursanon hope u check ur fb messages, all m...
# 14498  WowÌ_Ì__A Jewish man having his nose measured ...
# 14499  oldpicsarchive: A Jewish man having his nose m...
# 14500  A Jewish man having his nose measured during A...
# 14501  AO - aryan huy miss you na!! Happy that i'll b...
# 14502  @AryanTimsina Aryan, what is the version of Fifa?
# 14503  measured during Aryan race determination tests...
# 14504  I'm sorry. Did I offend your white supremacist...
# 14505  @tradethecycles Caucasian euro aryan whatever....
# 14506  @yadavakhilesh sir a patient named aryan khan ...
# 14507  @Iamshivachari  Happy birthday bro _Ì«ÌÐ_ \nHa...
# 14508  @Hajrahkiayni Aryan Kapoor is such a cute name...
#
# [14509 rows x 3 columns]

# %% [markdown]
# # Using Sklearn TFIDVectorizer to process text

# %%
#Cleaning
def clean(row):
    cleaned = ' '.join(re.sub('(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|([x][0-9]+)|([0-9]+)'," ",row).split())
    return cleaned
text['tweet_text'] = text['tweet_text'].apply(clean)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer

# %%
#Initialize Vectorizer
vect = TfidfVectorizer()
#vect = CountVectorizer() (0.84785005512679157 Logreg score vs 0.85005512679162076)
vect = TfidfVectorizer(ngram_range=(1, 2)) 
#intuition being that bi-gram can distinguish hate speech from offensive language, however there is tradeoff of adding more noise in hopes that it will help signal
#If using bigram change min df to 2, have at least twice
#Can tune stop-words, ngrams, max_df, min_df

# %%
regex_match = '(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|([x][0-9]+)|([0-9]+)'
#gets rid of Twitter handles, punctuation, urls, 'x89s etc., and all numbers

# %%
x = str(list(text["tweet_text"]))

# %%
corpus = (' '.join(re.sub(regex_match," ",x).split()))

# %%
#Fit Vectorizer
vect.fit(corpus.split())
# Out:
# TfidfVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 2), norm='l2', preprocessor=None, smooth_idf=True,
#         stop_words=None, strip_accents=None, sublinear_tf=False,
#         token_pattern='(?u)\\b\\w\\w+\\b', tokenizer=None, use_idf=True,
#         vocabulary=None)

# %%
#Looking at feature names
vect.get_feature_names()
# Out:
# ['aa',
#  'aaa',
#  'aaaw',
#  'aah',
#  'aahah',
#  'aaliyah',
#  'aap',
#  'aapadoptsrapists',
#  'aapl',
#  'aaron',
#  'aarp',
#  'aay',
#  'aays',
#  'ab',
#  'aba',
#  'abandoned',
#  'abandoning',
#  'abaytownies',
#  'abbott',
#  'abby',
#  'abc',
#  'abdomens',
#  'abdullah',
#  'abeg',
#  'abervet',
#  'abhorrent',
#  'abiding',
#  'abilities',
#  'ability',
#  'abilityfto',
#  'abimbola',
#  'abject',
#  'ablandoo',
#  'ablaze',
#  'able',
#  'ableg',
#  'ablht',
#  'abm',
#  'abndp',
#  'abnormal',
#  'abolished',
#  'abomination',
#  'aboot',
#  'aborting',
#  'abortion',
#  'about',
#  'above',
#  'abpoli',
#  'abracadabra',
#  'abrahamic',
#  'abroad',
#  'abs',
#  'absent',
#  'absolute',
#  'absolutely',
#  'absolutionist',
#  'absorbed',
#  'absoultely',
#  'abstinent',
#  'abstract',
#  'absurd',
#  'abt',
#  'abuela',
#  'abuelas',
#  'abuse',
#  'abused',
#  'abuser',
#  'abusing',
#  'abusive',
#  'aby',
#  'abyad',
#  'ac',
#  'acab',
#  'academic',
#  'academics',
#  'acc',
#  'accent',
#  'accents',
#  'accept',
#  'acceptable',
#  'acceptance',
#  'acceptancebfor',
#  'accepted',
#  'accepts',
#  'accessibility',
#  'accessible',
#  'accessing',
#  'accessories',
#  'accessory',
#  'accident',
#  'accidentally',
#  'acclaimed',
#  'accommodate',
#  'accomplish',
#  'accomplishments',
#  'accordance',
#  'according',
#  'account',
#  'accountability',
#  'accountable',
#  'accountant',
#  'accounting',
#  'accounts',
#  'accuracy',
#  'accurate',
#  'accuse',
#  'accused',
#  'accusing',
#  'ace',
#  'aces',
#  'acheive',
#  'achieve',
#  'achievement',
#  'achievements',
#  'achieving',
#  'achoo',
#  'acid',
#  'ackroyd',
#  'acl',
#  'acoustic',
#  'acquired',
#  'acquitted',
#  'acreage',
#  'acres',
#  'acrobat',
#  'across',
#  'acrylic',
#  'act',
#  'acted',
#  'actin',
#  'acting',
#  'action',
#  'actions',
#  'activate',
#  'activation',
#  'active',
#  'actively',
#  'activism',
#  'activist',
#  'activities',
#  'activity',
#  'actor',
#  'actress',
#  'acts',
#  'actual',
#  'actually',
#  'acustic',
#  'acv',
#  'acxounts',
#  'ad',
#  'ada',
#  'adachis',
#  'adam',
#  'adamsxtd',
#  'adapting',
#  'add',
#  'added',
#  'addict',
#  'addicted',
#  'addiction',
#  'addictive',
#  'adding',
#  'addition',
#  'additional',
#  'addled',
#  'addlepate',
#  'address',
#  'addressed',
#  'adds',
#  'addy',
#  'adeel',
#  'adele',
#  'adesina',
#  'adidas',
#  'adjudicating',
#  'adjusting',
#  'adjustment',
#  'adjusts',
#  'adl',
#  'admin',
#  'administrators',
#  'admins',
#  'admiral',
#  'admire',
#  'admit',
#  'admits',
#  'admitted',
#  'adobe',
#  'adonis',
#  'adopt',
#  'adoptable',
#  'adopted',
#  'adopters',
#  'adoption',
#  'adorable',
#  'adorns',
#  'adree',
#  'adress',
#  'adriannavorderbruggen',
#  'adrien',
#  'adrobsworstgift',
#  'ads',
#  'adult',
#  'adults',
#  'advance',
#  'advanced',
#  'advances',
#  'advantage',
#  'advantages',
#  'advent',
#  'adventure',
#  'adventures',
#  'adversaries',
#  'advert',
#  'advertisement',
#  'advertisementindia',
#  'advertisements',
#  'advertising',
#  'adverts',
#  'advice',
#  'advise',
#  'advisor',
#  'advocacy',
#  'advocate',
#  'ae',
#  'aeed',
#  'aereosky',
#  'aerith',
#  'aesome',
#  'aesthetic',
#  'af',
#  'afarid',
#  'afc',
#  'affair',
#  'affairs',
#  'affect',
#  'affective',
#  'affiliate',
#  'affirma',
#  'affliction',
#  'afford',
#  'affront',
#  'afghan',
#  'afghanistan',
#  'afghanistanattack',
#  'aficionado',
#  'afks',
#  'afra',
#  'afraid',
#  'africa',
#  'african',
#  'africans',
#  'afro',
#  'afte',
#  'after',
#  'afterall',
#  'aftermath',
#  'afternoon',
#  'aftershock',
#  'ag',
#  'agadir',
#  'again',
#  'against',
#  'age',
#  'aged',
#  'agege',
#  'ageing',
#  'agencies',
#  'agency',
#  'agenda',
#  'agendas',
#  'agent',
#  'agents',
#  'ages',
#  'agey',
#  'agg',
#  'aggies',
#  'aggression',
#  'aggressive',
#  'aging',
#  'agitations',
#  'aglife',
#  'agnostics',
#  'ago',
#  'agp',
#  'agree',
#  'agreed',
#  'agrees',
#  'agressive',
#  'agshdjf',
#  'aguero',
#  'ah',
#  'aha',
#  'ahaha',
#  'ahahahah',
#  'ahahhah',
#  'ahead',
#  'ahh',
#  'ahhdeex',
#  'ahhh',
#  'ahhhh',
#  'ahmad',
#  'ahshotel',
#  'ahya',
#  'ai',
#  'aib',
#  'aid',
#  'aiden',
#  'aids',
#  'aight',
#  'aigoo',
#  'aim',
#  'aimee',
#  'ain',
#  'aint',
#  'air',
#  'airbitz',
#  'airbnb',
#  'aircraft',
#  'airez',
#  'airing',
#  'airline',
#  'airplane',
#  'airport',
#  'airports',
#  'airways',
#  'aisle',
#  'aiwjsbkfnsbv',
#  'aja',
#  'ajmal',
#  'ak',
#  'aka',
#  'akbar',
#  'akere',
#  'akho',
#  'akil',
#  'akkad',
#  'ako',
#  'aks',
#  'aktastic',
#  'akusai',
#  'al',
#  'ala',
#  'alabama',
#  'aladdin',
#  'alahu',
#  'alam',
#  'alan',
#  'alana',
#  'alarm',
#  'alarming',
#  'alas',
#  'alaska',
#  'alaskan',
#  'albasha',
#  'albert',
#  'albino',
#  'albrite',
#  'albulm',
#  'album',
#  'albums',
#  'alchemist',
#  'alcohol',
#  'alcoholic',
#  'aldi',
#  'aldubangpagtatagpo',
#  'aldubmybebeloveparade',
#  'alejandra',
#  'aleppo',
#  'alert',
#  'alerts',
#  'alex',
#  'alexa',
#  'alexander',
#  'alexandra',
#  'alexfromtarget',
#  'alexis',
#  'alexthat',
#  'alexx',
#  'alfie',
#  'alfieri',
#  'algo',
#  'alhamdulilah',
#  'alhumdulilah',
#  'alice',
#  'alien',
#  'aliens',
#  'alike',
#  'alison',
#  'alive',
#  'aliyah',
#  'all',
#  'allaboutimage',
#  'allah',
#  'allahou',
#  'allahu',
#  'allahuakbar',
#  'allahumma',
#  'allat',
#  'alldatimengonumb',
#  'alleged',
#  'allegedly',
#  'allen',
#  'allergic',
#  'alley',
#  'alleys',
#  'allhalelee',
#  'allies',
#  'alllivesmatter',
#  'allll',
#  'allow',
#  'allowance',
#  'allowed',
#  'allowing',
#  'allows',
#  'alltimelow',
#  'ally',
#  'almeda',
#  'almellehan',
#  'almgren',
#  'almighty',
#  'almightyko',
#  'almightyy',
#  'almost',
#  'almostmerrychristmas',
#  'aloha',
#  'alone',
#  'along',
#  'alot',
#  'aloud',
#  'alph',
#  'alpha',
#  'already',
#  'alredy',
#  'alright',
#  'alsina',
#  'also',
#  'alt',
#  'alter',
#  'alternating',
#  'alternative',
#  'although',
#  'altright',
#  'alttp',
#  'aluminum',
#  'alumni',
#  'alv',
#  'always',
#  'alwayslookingperfect',
#  'alwys',
#  'alyssahill',
#  'am',
#  'ama',
#  'aman',
#  'amanthinketh',
#  'amaro',
#  'amas',
#  'amateur',
#  'amateurs',
#  'amawzng',
#  'amazed',
#  'amazes',
#  'amazing',
#  'amazingly',
#  'amazon',
#  'ambassador',
#  'amber',
#  'amberr',
#  'ambivalent',
#  'amd',
#  'ameen',
#  'amen',
#  'amendment',
#  'amenities',
#  'america',
#  'americablog',
#  'american',
#  'americans',
#  'americas',
#  'americunts',
#  'amerikkka',
#  'amiable',
#  'amid',
#  'amigenaboard',
#  'amiibo',
#  'amiibos',
#  'amirite',
#  'amish',
#  'ammo',
#  'ammunition',
#  'amod',
#  'among',
#  'amongst',
#  'amootu',
#  'amount',
#  'amp',
#  'amplifies',
#  'amputee',
#  'amr',
#  'ams',
#  'amsterdam',
#  'amunibuni',
#  'amurica',
#  'amusement',
#  'amwriting',
#  'an',
#  'ana',
#  'anachronists',
#  'anakin',
#  'anal',
#  'analingus',
#  'analogies',
#  'analogy',
#  'analysis',
#  'analyst',
#  'analytics',
#  'anatomy',
#  'ancestors',
#  'ancestral',
#  'anchor',
#  'ancientreality',
#  'and',
#  'andanotha',
#  'anderson',
#  'andersson',
#  'andres',
#  'andrew',
#  'andrewbath',
#  'androgynous',
#  'android',
#  'andy',
#  'ang',
#  'ange',
#  'angel',
#  'angela',
#  'angeles',
#  'angelica',
#  'angelinawho',
#  'angelou',
#  'angels',
#  'anger',
#  'angie',
#  'angle',
#  'anglers',
#  'angles',
#  'anglo',
#  'anglos',
#  'angola',
#  'angolan',
#  'angry',
#  'angst',
#  'anhbs',
#  'anhour',
#  'anikka',
#  'animal',
#  'animalcruelty',
#  'animalrights',
#  'animals',
#  'animated',
#  'anime',
#  'anit',
#  'anita',
#  'anjem',
#  'ankles',
#  'anna',
#  'annabelle',
#  'annai',
#  'annata',
#  'anndata',
#  'anne',
#  'annie',
#  'annihilation',
#  'anniversary',
#  'announce',
#  'announced',
#  'announcement',
#  'announcements',
#  'announcers',
#  'annoy',
#  'annoyed',
#  'annoying',
#  'annual',
#  'annulled',
#  'ano',
#  'anomaly',
#  'anon',
#  'anonymous',
#  'another',
#  'anr',
#  'anrtrtwoood',
#  'ans',
#  'ansar',
#  'ansari',
#  'answer',
#  'answered',
#  'answerin',
#  'answering',
#  'answerman',
#  'answers',
#  'ant',
#  'antarctic',
#  'anthem',
#  'anthony',
#  'anti',
#  'antichrist',
#  'anticipate',
#  'antics',
#  'antidote',
#  'antique',
#  'antisemitism',
#  'antlers',
#  'antofagasta',
#  'antonin',
#  'antoninscalia',
#  'antonio',
#  'anus',
#  'anw',
#  'anxiety',
#  'anxious',
#  'any',
#  'anybody',
#  'anybodys',
#  'anymies',
#  'anymore',
#  'anyone',
#  'anything',
#  'anytime',
#  'anyway',
#  'anyways',
#  'anywhere',
#  'anywhr',
#  'anza',
#  'ao',
#  'aoas',
#  'aoi',
#  'ap',
#  'apart',
#  'apartheid',
#  'apartment',
#  'apathetic',
#  'apc',
#  'ape',
#  'apes',
#  'apeshit',
#  'aphmau',
#  'aplyn',
#  'apocalypse',
#  'apolegma',
#  'apoligizes',
#  'apologies',
#  'apologise',
#  'apologised',
#  'apologist',
#  'apologize',
#  'apology',
#  'apostasy',
#  'app',
#  'appalachian',
#  'appalling',
#  'apparently',
#  'appeal',
#  'appeals',
#  'appear',
#  'appearances',
#  'appears',
#  'apperance',
#  'appetite',
#  'applauding',
#  'applause',
#  'apple',
#  'apples',
#  'appliances',
#  'applied',
#  'applies',
#  'apply',
#  'applying',
#  'appointment',
#  'appointments',
#  'appreciate',
#  'appreciating',
#  'appreciation',
#  'appreciationtweet',
#  'apprehended',
#  'approach',
#  'approached',
#  'appropriate',
#  'appropriating',
#  'approval',
#  'approve',
#  'approved',
#  'approves',
#  'approximate',
#  'approximately',
#  'apps',
#  'appt',
#  'apr',
#  'aps',
#  'apt',
#  'apts',
#  'aquamarine',
#  'aquarium',
#  'ar',
#  'arab',
#  'arabia',
#  'arabs',
#  'araldite',
#  'arbitrary',
#  'archaeologist',
#  'arched',
#  'archeology',
#  'archer',
#  'archibald',
#  'architect',
#  'architects',
#  'architecture',
#  'arcoiris',
#  'ard',
#  'ardi',
#  'ardor',
#  'are',
#  'area',
#  'areas',
#  'aren',
#  'arena',
#  'arent',
#  'arepa',
#  'ares',
#  'argan',
#  'argent',
#  'argentina',
#  'argue',
#  'argued',
#  'arguing',
#  'argument',
#  'arguments',
#  'ariana',
#  'arica',
#  'arin',
#  'arises',
#  'arisha',
#  'arizona',
#  'arkansas',
#  'arkie',
#  'arm',
#  'armageddon',
#  'armed',
#  'armeddon',
#  'arming',
#  'armistice',
#  'armitstead',
#  'armor',
#  'armour',
#  'armpit',
#  'armpits',
#  'arms',
#  'armstrong',
#  'army',
#  'armys',
#  'arnab',
#  'aroma',
#  'around',
#  'aroused',
#  'arpeggios',
#  'arranged',
#  'arrest',
#  'arrested',
#  'arresting',
#  'arrests',
#  'arriva',
#  'arrival',
#  'arrived',
#  'arriving',
#  'arrogance',
#  'arrogant',
#  'arrow',
#  'arrrr',
#  'arse',
#  'arsed',
#  'arsehole',
#  'arsenal',
#  'arsene',
#  'art',
#  'arteries',
#  'artfully',
#  'arthur',
#  'article',
#  'artist',
#  'artistic',
#  'arts',
#  'arvada',
#  'aryan',
#  'arzaylea',
#  'as',
#  'asap',
#  'asayish',
#  'ascender',
#  'ascot',
#  'asda',
#  'asf',
#  'ash',
#  'ashamed',
#  'ashley',
#  'ashton',
#  'ashtons',
#  'ashut',
#  'ashy',
#  'asia',
#  'asiaayana',
#  'asian',
#  'asians',
#  'asics',
#  'aside',
#  'asikho',
#  'ask',
#  'askalex',
#  'asked',
#  'asking',
#  'askmitt',
#  'askpanthera',
#  'askpcatt',
#  'askreddit',
#  'asks',
#  'asksimon',
#  'asl',
#  'asleep',
#  'asmr',
#  'asmsg',
#  'asociate',
#  'asphyxiation',
#  'ass',
#  'assad',
#  'assassin',
#  'assassinated',
#  'assassination',
#  'assassins',
#  'assaulted',
#  'assed',
#  'assembly',
#  'asseric',
#  'assert',
#  'asses',
#  'assess',
#  'assessment',
#  'assets',
#  'assfro',
#  'asshat',
#  'asshole',
#  'assholes',
#  'assigned',
#  'assimilation',
#  'assistant',
#  'assisting',
#  'associate',
#  'associated',
#  'association',
#  'asss',
#  'asst',
#  'assume',
#  'assumes',
#  'assuming',
#  'assumption',
#  'assumptions',
#  'assured',
#  'asswipes',
#  'astarto',
#  'astounding',
#  'astronaut',
#  'astronomy',
#  'asus',
#  'aswell',
#  'asylum',
#  'at',
#  'ata',
#  'atari',
#  'atcha',
#  'atchya',
#  'ate',
#  'atee',
#  'atfngrv',
#  'atheist',
#  'atheists',
#  'athens',
#  'atherosclerosis',
#  'athletes',
#  'atl',
#  'atlanta',
#  'atleast',
#  'atracks',
#  'atsocialmedia',
#  'atsume',
#  'attach',
#  'attached',
#  'attachment',
#  'attack',
#  'attacked',
#  'attacker',
#  'attacks',
#  'attempt',
#  'attempting',
#  'attempts',
#  'attend',
#  'attendent',
#  'attending',
#  'attention',
#  'attire',
#  'attitude',
#  'attitudes',
#  'attkisson',
#  'attorney',
#  'attracted',
#  'attraction',
#  'attractive',
#  'attracts',
#  'atv',
#  'atx',
#  'au',
#  'auction',
#  'audacity',
#  'audi',
#  'audience',
#  'audio',
#  'audiobook',
#  'augs',
#  'august',
#  'augusts',
#  'aunt',
#  'auntie',
#  'aunty',
#  'aura',
#  'aurora',
#  'auspol',
#  'austin',
#  'australia',
#  'australian',
#  'authentic',
#  'authenticator',
#  'authenticity',
#  'author',
#  'authorinterviews',
#  'authority',
#  'autism',
#  'autist',
#  'autistic',
#  'auto',
#  'autocorrect',
#  'autographs',
#  'automatic',
#  'automatically',
#  'automaticly',
#  'autoplay',
#  'autoposted',
#  'av',
#  'avail',
#  'available',
#  'avance',
#  'avatar',
#  'ave',
#  'avenue',
#  'average',
#  'avi',
#  'aviame',
#  'avin',
#  'avocado',
#  'avoid',
#  'avoided',
#  'avsed',
#  'aw',
#  'awaaaaay',
#  'awaits',
#  'awake',
#  'awakened',
#  'awakens',
#  'award',
#  'awarded',
#  'awards',
#  'aware',
#  'away',
#  'aways',
#  'awe',
#  'awesome',
#  'awesomenauts',
#  'awf',
#  'awful',
#  'awhile',
#  'awkward',
#  'awkwardly',
#  'awsm',
#  'aww',
#  'awww',
#  'awwww',
#  'awwwwwww',
#  'ax',
#  'ay',
#  'ayan',
#  'ayane',
#  'ayatobot',
#  'ayatotally',
#  'aye',
#  'ayh',
#  'ayo',
#  ...]

# %%
#encode
text['does_this_tweet_contain_hate_speech'] = text.does_this_tweet_contain_hate_speech.map({'The tweet uses offensive language but not hate speech':0, 'The tweet is not offensive':0, 'The tweet contains hate speech':1})

# %%
text
# Out:
#        does_this_tweet_contain_hate_speech  \
# 0                                        0
# 1                                        1
# 2                                        1
# 3                                        1
# 4                                        0
# 5                                        1
# 6                                        1
# 7                                        1
# 8                                        0
# 9                                        0
# 10                                       1
# 11                                       1
# 12                                       1
# 13                                       1
# 14                                       1
# 15                                       1
# 16                                       1
# 17                                       0
# 18                                       1
# 19                                       0
# 20                                       1
# 21                                       1
# 22                                       0
# 23                                       0
# 24                                       0
# 25                                       0
# 26                                       0
# 27                                       0
# 28                                       0
# 29                                       0
# ...                                    ...
# 14479                                    0
# 14480                                    0
# 14481                                    0
# 14482                                    0
# 14483                                    1
# 14484                                    0
# 14485                                    0
# 14486                                    0
# 14487                                    0
# 14488                                    0
# 14489                                    0
# 14490                                    1
# 14491                                    0
# 14492                                    0
# 14493                                    0
# 14494                                    0
# 14495                                    0
# 14496                                    0
# 14497                                    0
# 14498                                    0
# 14499                                    0
# 14500                                    0
# 14501                                    0
# 14502                                    0
# 14503                                    0
# 14504                                    0
# 14505                                    0
# 14506                                    0
# 14507                                    0
# 14508                                    0
#
#        does_this_tweet_contain_hate_speech:confidence  \
# 0                                              0.6013
# 1                                              0.7227
# 2                                              0.5229
# 3                                              0.5184
# 4                                              0.5185
# 5                                              0.8816
# 6                                              0.5207
# 7                                              0.5619
# 8                                              0.6419
# 9                                              0.6407
# 10                                             0.7619
# 11                                             0.5606
# 12                                             0.8435
# 13                                             0.8414
# 14                                             0.8826
# 15                                             0.7620
# 16                                             0.6833
# 17                                             0.5204
# 18                                             0.6410
# 19                                             0.6419
# 20                                             0.7608
# 21                                             0.9221
# 22                                             1.0000
# 23                                             1.0000
# 24                                             0.9218
# 25                                             0.9204
# 26                                             1.0000
# 27                                             0.8388
# 28                                             1.0000
# 29                                             1.0000
# ...                                               ...
# 14479                                          1.0000
# 14480                                          0.6771
# 14481                                          1.0000
# 14482                                          0.6683
# 14483                                          0.6684
# 14484                                          1.0000
# 14485                                          0.3351
# 14486                                          0.6615
# 14487                                          1.0000
# 14488                                          1.0000
# 14489                                          1.0000
# 14490                                          0.6633
# 14491                                          0.6616
# 14492                                          1.0000
# 14493                                          1.0000
# 14494                                          0.6579
# 14495                                          1.0000
# 14496                                          1.0000
# 14497                                          1.0000
# 14498                                          1.0000
# 14499                                          1.0000
# 14500                                          0.6684
# 14501                                          1.0000
# 14502                                          1.0000
# 14503                                          1.0000
# 14504                                          0.3418
# 14505                                          0.6804
# 14506                                          1.0000
# 14507                                          1.0000
# 14508                                          1.0000
#
#                                               tweet_text
# 0            Warning penny boards will make you a faggot
# 1                                             Fuck dykes
# 2      chulo at least i dont look like jefree starr f...
# 3                         Is a fag jackie jealous Neeeee
# 4      You heard me bitch but any way I m back th tex...
# 5      your a dirty terrorist and your religion is a ...
# 6                    RT WhitePonyJr looking like faggots
# 7      Well I thought you knew actually RT Man why y ...
# 8                            I know It was a joke faggot
# 9      I m tired of people saying I look like my brot...
# 10     VoteBlue Yeah CUZ million people in faggot ass...
# 11     word is you use roids stupid hypocrite lying f...
# 12                               I hate faggots like you
# 13     shut up nigger whore Hope u get raped by one o...
# 14     Fuck you nigger sheboon Hope you r strung up l...
# 15     They used to tie both ends of a niggers legs t...
# 16     Good night fags and fagettes that s the female...
# 17     I cant stand no crybaby ass nigga If you gonna...
# 18                                 RT no you re a nigger
# 19       I ll fuck you til you love me faggot Mike Tyson
# 20     what s your problem Don t u know Jews control ...
# 21                       I fucking hate you niggers bruh
# 22     RT Some species of birds have been known to ho...
# 23     I remember Draft prom night my dress wouldn t ...
# 24     Damn Eli That s just ruff I m not even gonna t...
# 25     Also Happy Armistice Day anachronists The Hun ...
# 26     A friend suggested I dress as a Fairy for a Ha...
# 27     RT apparently bae means before anyone else i a...
# 28     so I was suspended for a day because of a rand...
# 29     Flyers w some moxy Big comeback again Major pe...
# ...                                                  ...
# 14479  I can t deal with a slow internet connection J...
# 14480  Mental Health Practitioner Coon Rapids Day Tre...
# 14481  Mental Health Practitioner Coon Rapids Day Tre...
# 14482  Mental Health Practitioner Coon Rapids Day Tre...
# 14483  Ben Carson thinks it s okay to have A confeder...
# 14484  YodaSpeakASaying Kills captivity does Death an...
# 14485  diamond keep actin up ima go to her job and be...
# 14486                 Cries I m turning into a weeb coon
# 14487  Saw this gorgeous year old Maine Coon today Sh...
# 14488  Jet Stream the Maine Coon riding out last nigh...
# 14489                           I m not even a coon girl
# 14490  From what I ve seen men and women coon at the ...
# 14491  BW take care of me pls buy my coon ass somethi...
# 14492  Interesting data on quantifying value of the I...
# 14493                                      twr thank you
# 14494  if he is Aryan then mallikarjun will say him t...
# 14495  sir if he is Aryan then mallikarjun will ask h...
# 14496  Radio Nordfront interview a Russian patriot an...
# 14497  hope u check ur fb messages all message reques...
# 14498  Wow A Jewish man having his nose measured duri...
# 14499  oldpicsarchive A Jewish man having his nose me...
# 14500  A Jewish man having his nose measured during A...
# 14501  AO aryan huy miss you na Happy that i ll be ab...
# 14502                  Aryan what is the version of Fifa
# 14503  measured during Aryan race determination tests...
# 14504  I m sorry Did I offend your white supremacist ...
# 14505  Caucasian euro aryan whatever Really doesn t m...
# 14506  sir a patient named aryan khan village meeranp...
# 14507        Happy birthday bro Have an happy year ahead
# 14508  Aryan Kapoor is such a cute name tho D We Want...
#
# [14509 rows x 3 columns]

# %%
# define X and y
X = text.tweet_text
y = text.does_this_tweet_contain_hate_speech
print(X.shape)
print(y.shape)
# Out:
# (14509,)
# (14509,)

# %%
# split X and y into training and testing sets
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10881,)
# (3628,)
# (10881,)
# (3628,)

# %%
# learn training data vocabulary, then used it to create a document-term matrix
vect.fit(X_train)
X_train_dtm = vect.transform(X_train)

# %%
# examine the document-term matrix
X_train_dtm
# Out:
# <10881x82394 sparse matrix of type '<class 'numpy.float64'>'
# 	with 257532 stored elements in Compressed Sparse Row format>

# %%
# transform testing data (using fitted vocabulary) into a document-term matrix
X_test_dtm = vect.transform(X_test)
X_test_dtm
# Out:
# <3628x82394 sparse matrix of type '<class 'numpy.float64'>'
# 	with 65214 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Using Logistic Regression

# %%
# import and instantiate a logistic regression model
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression(C=10)

# %%
# train the model using X_train_dtm
# %time logreg.fit(X_train_dtm, y_train)
# Out:
# CPU times: user 166 ms, sys: 7.43 ms, total: 173 ms
# Wall time: 192 ms
# LogisticRegression(C=10, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
y_train.shape
# Out:
# (10881,)

# %%
X_train_dtm.shape
# Out:
# (10881, 82394)

# %%
# make class predictions for X_test_dtm
y_pred_class = logreg.predict(X_test_dtm)

# %%
# calculate accuracy
from sklearn import metrics
metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.85033076074972436

# %%
#Find best parameters
from sklearn.grid_search import GridSearchCV
C_test = [0.00001, 0.0001, 0.001, 0.01, 0.1, 1, 10, 100, 1000]
param_grid = dict(C=C_test)
grid =GridSearchCV(logreg, param_grid, cv =10, scoring = 'accuracy')
grid.fit(X_train_dtm, y_train)
grid.grid_scores_
# Out:
# /Users/sparajuli/anaconda3/lib/python3.6/site-packages/sklearn/grid_search.py:43: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)
# [mean: 0.83715, std: 0.00030, params: {'C': 1e-05},
#  mean: 0.83715, std: 0.00030, params: {'C': 0.0001},
#  mean: 0.83715, std: 0.00030, params: {'C': 0.001},
#  mean: 0.83715, std: 0.00030, params: {'C': 0.01},
#  mean: 0.83733, std: 0.00079, params: {'C': 0.1},
#  mean: 0.84533, std: 0.00520, params: {'C': 1},
#  mean: 0.84459, std: 0.00700, params: {'C': 10},
#  mean: 0.84156, std: 0.00634, params: {'C': 100},
#  mean: 0.84055, std: 0.00659, params: {'C': 1000}]

# %%
null_score = 12110/14509
null_score
# Out:
# 0.8346543524708802

# %% [markdown]
# # Using KNN

# %%
from sklearn import neighbors

# %%
knn = neighbors.KNeighborsClassifier()

# %%
# %time knn.fit(X_train_dtm, y_train)
# Out:
# CPU times: user 2.31 ms, sys: 440 µs, total: 2.75 ms
# Wall time: 2.56 ms
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#            weights='uniform')

# %%
y_pred_class = knn.predict(X_test_dtm)

# %%
metrics.accuracy_score(y_test, y_pred_class)
# Out:
# 0.827728776185226

# %%
n_neighbors_test = [1, 5, 10, 15, 50, 60, 70, 80 ,90]
param_grid = dict(n_neighbors=n_neighbors_test)
grid =GridSearchCV(knn, param_grid, cv =10, scoring = 'accuracy')
grid.fit(X_train_dtm, y_train)
grid.grid_scores_
# Out:
# [mean: 0.78421, std: 0.01553, params: {'n_neighbors': 1},
#  mean: 0.82198, std: 0.01114, params: {'n_neighbors': 5},
#  mean: 0.83623, std: 0.00651, params: {'n_neighbors': 10},
#  mean: 0.83485, std: 0.00607, params: {'n_neighbors': 15},
#  mean: 0.84321, std: 0.00429, params: {'n_neighbors': 50},
#  mean: 0.84183, std: 0.00471, params: {'n_neighbors': 60},
#  mean: 0.84092, std: 0.00517, params: {'n_neighbors': 70},
#  mean: 0.84064, std: 0.00410, params: {'n_neighbors': 80},
#  mean: 0.83908, std: 0.00465, params: {'n_neighbors': 90}]

# %% [markdown]
# # Using Keras

# %%
from keras.models import Sequential
twitter_model = Sequential()

# %%
from keras.layers import Dense
twitter_model.add(Dense(32, input_shape=(82394,)))

# %%
from keras.layers import Activation
twitter_model.add(Activation('sigmoid'))

# %%
twitter_model.add(Dense(1))

# %%
twitter_model.compile(optimizer='SGD', loss='binary_crossentropy', metrics = ['accuracy'])

# %%
twitter_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 32)                2636640
# _________________________________________________________________
# activation_2 (Activation)    (None, 32)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 2,636,673
# Trainable params: 2,636,673
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Changing from sparse matrix to dense
A= X_train_dtm
A = A.todense()

# %%
twitter_model.fit(A, y_train, epochs=1)
# Out:
# Epoch 1/1
#  4128/10881 [==========>...................] - ETA: 19s - loss: 0.4691 - acc: 0.8251

# %%
# Changing from sparse matrix to dense
B=X_test_dtm
B = B.todense()

# %%
#Evaluating
twitter_model.evaluate(B, y_test)
# Out:
# 2848/3628 [======================>.......] - ETA: 1s
